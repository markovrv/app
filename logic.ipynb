# %% [markdown]
# <a href="https://colab.research.google.com/github/markovrv/app/blob/master/logic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Дискретная математика с элементами математической логики
#
# ---
#
#
# # Алгебра высказываний
# *Практическая работа №1*

# %% [markdown]
# ## Задача №1
# Среди приведенных ниже предложений указать те, которые являются высказываниями и те, которые не являются:
# 1. Екатеринбург - столица Урала;
# 2. студент Вятского государственного университета
# 3. Луна - спутник Земли;
# 4. $x<0$ ;
# 5. Число $\sqrt 5$ - иррациональное.

# %% [markdown]
# ## Задача №2
# Среди следующих высказываний указать элементарные и составные, в составных высказываниях выделить грамматические связки:
# 1. число 9 не делится на 3;
# 1. число 21 делится на 3 и на 7;
# 1. число 3 является делителем числа 27;
# 1. если число 15 делится на 5, то оно делится на 3;
# 1. число 18 делится на 9 тогда и только тогда, когда 9 делится на 3.

# %% [markdown]
# ## Задача №3
# Среди следующих предложений определить высказывания, установить, истинны они или ложны:
# 1. река Исеть впадает в Каспийское море;
# 2. пейте апельсиновый сок;
# 3. все люди - братья;
# 4. математическая логика - увлекательная наука;
# 5. если стол дубовый, значит он деревянный;
# 6. $5<4$;
# 6. $x^2-5x+9$;
# 6. $x^2-5x+9=0$;
# 6. для всех натуральных чисел $x$ и $y$ верно равенство $x+y=y+x$.

# %% [markdown]
# ## Задача №4
# Являются ли высказываниями следующие утверждения, установить, истинны они или ложны:
# 1. сумма корней любого приведенного квадратного уравнения равна свободному члену
# 2. сумма корней приведенного квадратного уравнения равна свободному члену
# 2. сумма корней приведенного квадратного уравнения не равна свободному члену
# 3. существует приведенное квадратное уравнение, сумма корней которого равна свободному члену

# %% [markdown]
# ## Задача №5
# Пусть $x-$ высказывание "*Студент Сидоров изучает информатику*", $y-$ высказывание "*Студент Сидоров успевает по математической логике*". Дать словесную формулировку следующих высказываний:
# 1. $x \wedge\bar y$
# 1. $\overline {x \vee y}$
# 1. $\bar x \leftrightarrow  \bar y$
# 1. $x \rightarrow  y$

# %% [markdown]
# ## Задача №6
# Пусть $x$ и $y$ обозначают элементарные высказывания:
#  - $x-$ "*я учусь в ВятГУ*";
#  - $y-$"*я люблю математическую логику*".
#
#  Прочитать следующие высказывания:
#  1. $\overline {\overline x}$
#  2. $x \wedge y$
#  2. $x \wedge \overline y$
#  2. $\overline x \wedge \overline y$
#  2. $\overline {x \wedge y}$

# %% [markdown]
# ## Задача №7
# Выяснить истинность или ложность следующих импликаций:
# 1. если $2\cdot 2=4$, то $4>5$
# 1. если $2\cdot 2=4$, то $4<5$
# 1. если $2\cdot 2=5$, то $4>5$
# 1. если $2\cdot 2=5$, то $4<5$

# %% [markdown]
# ## Задача №8
# Выяснить, при каких значениях $y$ следующие данные противоречивы:
# 1. $x=0, (x=1)\wedge(y=1)$
# 1. $x=1, (x=0)\wedge(y=0)$
# 1. $x=0, (x=1)\vee(y=1)$
# 1. $x=1, (x=0)\vee(y=0)$

# %% [markdown]
# ## Задача №9 (домашнее задание)
# Пусть
#  - $x=$"*3-простое число*" ,
#  - $y=$"*3-составное число*",
#  - $z=$"*4-простое число*",
#  - $w=$"*4-составное число*"
# $-$ элементарные высказывания. Какие изследующих составных высказываний истинны, а какие ложны:
# 1. $x\vee z, x\vee w, y\vee z, y\vee w$
# 1. $\overline x\wedge \overline z, \overline x\wedge \overline w, \overline y\wedge \overline z, \overline y\wedge \overline w$

# %% [markdown]
# ## Задача №10 (домашнее задание)
# Выяснить, при каких значениях $y$ следующие данные противоречивы:
# 1. $x=0,(x=1)\wedge (y=1)$
# 1. $x=0,(x=1)\vee (y=1)$
# 1. $x=1,(x=0)\wedge (y=0)$
# 1. $x=1,(x=0)\vee (y=0)$
